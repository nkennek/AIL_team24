# %%
# %matplotlib inline

import sys
import os

import cv2
import dlib
import numpy as np

# %%
sys.path.append('../face_landmark/')

# %%
from face_landmark import LandmarkDetector

# %%
detector = LandmarkDetector()

detector.plot('../../data/download/00426538bc2d41570aaa84ebc6eaa61a7c53370d.jpg')
# Out:
# (array([[[215, 211, 192],
#          [215, 211, 192],
#          [215, 211, 192],
#          ...,
#          [188, 189, 173],
#          [187, 188, 172],
#          [186, 187, 171]],
#
#         [[215, 211, 192],
#          [215, 211, 192],
#          [216, 212, 193],
#          ...,
#          [189, 190, 174],
#          [189, 190, 174],
#          [188, 189, 173]],
#
#         [[216, 212, 193],
#          [216, 212, 193],
#          [216, 212, 193],
#          ...,
#          [191, 192, 176],
#          [190, 191, 175],
#          [189, 190, 174]],
#
#         ...,
#         [[144, 153, 143],
#          [142, 151, 141],
#          [142, 150, 143],
#          ...,
#          [234, 234, 220],
#          [234, 234, 220],
#          [234, 234, 220]],
#
#         [[144, 153, 143],
#          [142, 151, 141],
#          [142, 150, 143],
#          ...,
#          [234, 234, 220],
#          [234, 234, 220],
#          [234, 234, 220]],
#
#         [[144, 153, 143],
# ...
